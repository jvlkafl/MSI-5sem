# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn import preprocessing as p

es = EarlyStopping(monitor = "val_loss", mode = "min", patience = 3)
EPOCHS = 100

df = pd.read_table('./datasets/tested.csv', sep = ',')
# Out:
# c:\Users\Lenovo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#wyświetl df
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
#wyświelt podsumowanie df za pomocą describe. Co jest alarmujące?
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#wyrzuć z df te kolumny, które prawdopodobnie nic nie wnoszą
df = df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis = 1)

# %%
#wyświetl df
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  34.5      0      0    7.8292        Q
# 1           1       3  female  47.0      1      0    7.0000        S
# 2           0       2    male  62.0      0      0    9.6875        Q
# 3           0       3    male  27.0      0      0    8.6625        S
# 4           1       3  female  22.0      1      1   12.2875        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 413         0       3    male   NaN      0      0    8.0500        S
# 414         1       1  female  39.0      0      0  108.9000        C
# 415         0       3    male  38.5      0      0    7.2500        S
# 416         0       3    male   NaN      0      0    8.0500        S
# 417         0       3    male   NaN      1      1   22.3583        C
#
# [418 rows x 8 columns]

# %%
#użyj one-hot encoding na danych nominalnych
temp = pd.get_dummies(df.Sex, prefix='is')
temp2 = pd.get_dummies(df.Embarked, prefix='is')

# %%
df['Sex_female']=temp['is_female']
df['Embarked_C'] = temp2['is_C']
df['Embarked_Q'] = temp2['is_Q']

# %%
#wyświetl df
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked  \
# 0           0       3    male  34.5      0      0    7.8292        Q
# 1           1       3  female  47.0      1      0    7.0000        S
# 2           0       2    male  62.0      0      0    9.6875        Q
# 3           0       3    male  27.0      0      0    8.6625        S
# 4           1       3  female  22.0      1      1   12.2875        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 413         0       3    male   NaN      0      0    8.0500        S
# 414         1       1  female  39.0      0      0  108.9000        C
# 415         0       3    male  38.5      0      0    7.2500        S
# 416         0       3    male   NaN      0      0    8.0500        S
# 417         0       3    male   NaN      1      1   22.3583        C
#
#      Sex_female  Embarked_C  Embarked_Q
# 0         False       False        True
# 1          True       False       False
# 2         False       False        True
# 3         False       False       False
# 4          True       False       False
# ..          ...         ...         ...
# 413       False       False       False
# 414        True        True       False
# 415       False       False       False
# 416       False       False       False
# 417       False        True       False
#
# [418 rows x 11 columns]

# %%
#usuń nadmiarowe kolumny
df=df.drop(columns='Sex')
df=df.drop(columns='Embarked')

# %%
#wyświetl df
df
# Out:
#      Survived  Pclass   Age  SibSp  Parch      Fare  Sex_female  Embarked_C  \
# 0           0       3  34.5      0      0    7.8292       False       False
# 1           1       3  47.0      1      0    7.0000        True       False
# 2           0       2  62.0      0      0    9.6875       False       False
# 3           0       3  27.0      0      0    8.6625       False       False
# 4           1       3  22.0      1      1   12.2875        True       False
# ..        ...     ...   ...    ...    ...       ...         ...         ...
# 413         0       3   NaN      0      0    8.0500       False       False
# 414         1       1  39.0      0      0  108.9000        True        True
# 415         0       3  38.5      0      0    7.2500       False       False
# 416         0       3   NaN      0      0    8.0500       False       False
# 417         0       3   NaN      1      1   22.3583       False        True
#
#      Embarked_Q
# 0          True
# 1         False
# 2          True
# 3         False
# 4         False
# ..          ...
# 413       False
# 414       False
# 415       False
# 416       False
# 417       False
#
# [418 rows x 9 columns]

# %%
#wypełnij braki danych w kolumne Age za pomocą sredniej wartości z tej kolumny

mean_value = df["Age"].mean()
df = df.fillna(mean_value)

# %%
#skalujemy do wartości 0-1 tylko wybrane kolumny. W tej komórce nie musisz nic robić
cols_to_scale = ['Pclass','Age','Fare']

scaler = p.StandardScaler().fit(df[cols_to_scale])

df[cols_to_scale] = scaler.transform(df[cols_to_scale])

# %%
#wyświetl df
df
# Out:
#      Survived    Pclass       Age  SibSp  Parch      Fare  Sex_female  \
# 0           0  0.873482  0.334993      0      0 -0.498172       False
# 1           1  0.873482  1.325530      1      0 -0.513039        True
# 2           0 -0.315819  2.514175      0      0 -0.464854       False
# 3           0  0.873482 -0.259330      0      0 -0.483231       False
# 4           1  0.873482 -0.655545      1      1 -0.418237        True
# ..        ...       ...       ...    ...    ...       ...         ...
# 413         0  0.873482  0.000000      0      0 -0.494213       False
# 414         1 -1.505120  0.691586      0      0  1.313968        True
# 415         0  0.873482  0.651965      0      0 -0.508557       False
# 416         0  0.873482  0.000000      0      0 -0.494213       False
# 417         0  0.873482  0.000000      1      1 -0.237674       False
#
#      Embarked_C  Embarked_Q
# 0         False        True
# 1         False       False
# 2         False        True
# 3         False       False
# 4         False       False
# ..          ...         ...
# 413       False       False
# 414        True       False
# 415       False       False
# 416       False       False
# 417        True       False
#
# [418 rows x 9 columns]

# %%
#podział df na dane i labele 
X = df[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_female', 'Embarked_C', 'Embarked_Q']]
y = df[['Survived']]

# %%
#podziel X i y na zbiory uczące i testowe za pomocą train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#zbuduj modej sieci. W tym przypadku ostatnia warstwa powinna mieć jeden neuron i sigmoidalną funkcję aktywacji
model = Sequential()
model.add(Dense(32, activation='relu', input_dim=8))
model.add(Dense(1, activation='sigmoid'))

# %%
#binary_crossentropy bo mamy tylko jeden neuron z sigmoidalną funkcją aktywacji
model.compile(loss = "binary_crossentropy", optimizer = 'adam', metrics=["accuracy"])

# %%
#naucz sieć
X_train = X_train.astype('float32')
y_train = y_train.astype('float32')

history = model.fit(X_train, y_train, epochs=EPOCHS, validation_split=0.2, callbacks=[es])
# Out:
# Epoch 1/100
# 9/9 [==============================] - 3s 128ms/step - loss: 0.7662 - accuracy: 0.4569 - val_loss: 0.7346 - val_accuracy: 0.4776
# Epoch 2/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.7409 - accuracy: 0.4682 - val_loss: 0.7155 - val_accuracy: 0.4776
# Epoch 3/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.7157 - accuracy: 0.5094 - val_loss: 0.6985 - val_accuracy: 0.5224
# Epoch 4/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.6938 - accuracy: 0.6854 - val_loss: 0.6828 - val_accuracy: 0.7463
# Epoch 5/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.6728 - accuracy: 0.7828 - val_loss: 0.6668 - val_accuracy: 0.8060
# Epoch 6/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.6526 - accuracy: 0.7903 - val_loss: 0.6513 - val_accuracy: 0.8507
# Epoch 7/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.6340 - accuracy: 0.7978 - val_loss: 0.6368 - val_accuracy: 0.8507
# Epoch 8/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.
100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1723 - accuracy: 0.9963 - val_loss: 0.1672 - val_accuracy: 1.0000
# Epoch 39/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1632 - accuracy: 0.9963 - val_loss: 0.1582 - val_accuracy: 1.0000
# Epoch 40/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1544 - accuracy: 0.9963 - val_loss: 0.1492 - val_accuracy: 1.0000
# Epoch 41/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1465 - accuracy: 0.9963 - val_loss: 0.1401 - val_accuracy: 1.0000
# Epoch 42/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1384 - accuracy: 0.9963 - val_loss: 0.1326 - val_accuracy: 1.0000
# Epoch 43/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1311 - accuracy: 0.9963 - val_loss: 0.1260 - val_accuracy: 1.0000
# Epoch 44/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1242 - accuracy: 0.9963 - val_loss: 0.1198 - val_accuracy: 1.0000
# Epoch 45/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1178 - accuracy: 0.9963 - val_loss: 0.1136 - val_accuracy: 1.0000
# Epoch 46/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1116 - accuracy: 0.9963 - val_loss: 0.1080 - val_accuracy: 1.0000
# Epoch 47/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1059 - accuracy: 0.9963 - val_loss: 0.1026 - val_accuracy: 1.0000
# Epoch 48/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1004 - accuracy: 0.9963 - val_loss: 0.0976 - val_accuracy: 1.0000
# Epoch 49/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0954 - accuracy: 0.9963 - val_loss: 0.0933 - val_accuracy: 1.0000
# Epoch 50/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0907 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 1.0000
# Epoch 51/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0861 - accuracy: 1.0000 - val_loss: 0.0841 - val_accuracy: 1.0000
# Epoch 52/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0818 - accuracy: 1.0000 - val_loss: 0.0804 - val_accuracy: 1.0000
# Epoch 53/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0778 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 1.0000
# Epoch 54/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0741 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 1.0000
# Epoch 55/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0704 - accuracy: 1.0000 - val_loss: 0.0696 - val_accuracy: 1.0000
# Epoch 56/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0671 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 1.0000
# Epoch 57/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0639 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 1.0000
# Epoch 58/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0609 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 1.0000
# Epoch 59/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0582 - accuracy: 1.0000 - val_loss: 0.0580 - val_accuracy: 1.0000
# Epoch 60/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0555 - accuracy: 1.0000 - val_loss: 0.0556 - val_accuracy: 1.0000
# Epoch 61/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0531 - accuracy: 1.0000 - val_loss: 0.0532 - val_accuracy: 1.0000
# Epoch 62/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.0509 - val_accuracy: 1.0000
# Epoch 63/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0485 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 1.0000
# Epoch 64/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0464 - accuracy: 1.0000 - val_loss: 0.0468 - val_accuracy: 1.0000
# Epoch 65/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0446 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 1.0000
# Epoch 66/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0427 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 1.0000
# Epoch 67/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0410 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 68/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0394 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 1.0000
# Epoch 69/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 1.0000
# Epoch 70/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 1.0000
# Epoch 71/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 72/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0338 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 1.0000
# Epoch 73/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 74/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.0323 - val_accuracy: 1.0000
# Epoch 75/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 1.0000
# Epoch 76/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0291 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 1.0000
# Epoch 77/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 78/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 1.0000
# Epoch 79/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 1.0000
# Epoch 80/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 1.0000
# Epoch 81/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 1.0000
# Epoch 82/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 83/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 1.0000
# Epoch 84/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 1.0000
# Epoch 85/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 1.0000
# Epoch 86/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 1.0000
# Epoch 87/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 88/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 89/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 90/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 91/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 92/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 93/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 1.0000
# Epoch 94/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 95/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 96/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 97/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 98/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 99/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 100/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 1.0000

# %%
#wyświetl wykresy uczenia
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.subplot(1,2,1)
plt.plot(loss, label = "loss")
plt.plot(val_loss, label = "val_loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.subplot(1,2,2)
plt.plot(acc, label = "accuracy")
plt.plot(val_acc, label = "val_accuracy")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend()
plt.show()
plt.tight_layout()
