# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
EPOCHS = 100
# Out:
# c:\Users\Lenovo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Przygotowanie danych
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

# %%
#ile czasu zajmuje jeden krok dla poszczególnych wartości batch size?
batch_sizes = [8, 16, 32, 64, 128, 256]
histories = []

for batch_size in batch_sizes:
    print(f"Ustawiona wielość zbioru: {batch_size}")
    model = Sequential([
        Flatten(input_shape=(28, 28, 1)),
        Dense(128, activation='relu'),
        Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    history = model.fit(train_images, train_labels, epochs=5, batch_size=batch_size, validation_data=(test_images, test_labels))
    histories.append(history)
# Out:
# Ustawiona wielość zbioru: 8
# Epoch 1/5
# 7500/7500 [==============================] - 57s 7ms/step - loss: 0.2079 - accuracy: 0.9395 - val_loss: 0.1085 - val_accuracy: 0.9668
# Epoch 2/5
# 7500/7500 [==============================] - 59s 8ms/step - loss: 0.0938 - accuracy: 0.9709 - val_loss: 0.0859 - val_accuracy: 0.9742
# Epoch 3/5
# 7500/7500 [==============================] - 44s 6ms/step - loss: 0.0678 - accuracy: 0.9790 - val_loss: 0.0855 - val_accuracy: 0.9758
# Epoch 4/5
# 7500/7500 [==============================] - 37s 5ms/step - loss: 0.0505 - accuracy: 0.9838 - val_loss: 0.0706 - val_accuracy: 0.9787
# Epoch 5/5
# 7500/7500 [==============================] - 43s 6ms/step - loss: 0.0393 - accuracy: 0.9868 - val_loss: 0.0844 - val_accuracy: 0.9765
# Ustawiona wielość zbioru: 16
# Epoch 1/5
# 3750/3750 [==============================] - 22s 5ms/step - loss: 0.2265 - accuracy: 0.9344 - val_loss: 0.1162 - val_accuracy: 0.9640
# Epoch 2/5
# 3750/3750 [==============================] - 18s 5ms/step - loss: 0.0977 - accuracy: 0.9703 - val_loss: 0.0940 - val_accuracy: 0.9710
# Epoch 3/5
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.0668 - accuracy: 0.9788 - val_loss: 0.0750 - val_accuracy: 0.9778
# Epoch 4/5
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.0499 - accuracy: 0.9841 - val_loss: 0.0793 - val_accuracy: 0.9762
# Epoch 5/5
# 3750/3750 [==============================] - 22s 6ms/step - loss: 0.0391 - accuracy: 0.9873 - val_loss: 0.0749 - val_accuracy: 0.9778
# Ustawiona wielość zbioru: 32
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2615 - accuracy: 0.9248 - val_loss: 0.1385 - val_accuracy: 0.9589
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1145 - accuracy: 0.9665 - val_loss: 0.1093 - val_accuracy: 0.9698
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0774 - accuracy: 0.9769 - val_loss: 0.1008 - val_accuracy: 0.9688
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0598 - accuracy: 0.9819 - val_loss: 0.0818 - val_accuracy: 0.9736
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0445 - accuracy: 0.9866 - val_loss: 0.0826 - val_accuracy: 0.9723
# Ustawiona wielość zbioru: 64
# Epoch 1/5
# 938/938 [==============================] - 6s 5ms/step - loss: 0.3032 - accuracy: 0.9142 - val_loss: 0.1615 - val_accuracy: 0.9537
# Epoch 2/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1335 - accuracy: 0.9612 - val_loss: 0.1102 - val_accuracy: 0.9678
# Epoch 3/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0929 - accuracy: 0.9728 - val_loss: 0.0961 - val_accuracy: 0.9711
# Epoch 4/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0708 - accuracy: 0.9790 - val_loss: 0.0825 - val_accuracy: 0.9745
# Epoch 5/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0552 - accuracy: 0.9833 - val_loss: 0.0854 - val_accuracy: 0.9739
# Ustawiona wielość zbioru: 128
# Epoch 1/5
# 469/469 [==============================] - 4s 6ms/step - loss: 0.3581 - accuracy: 0.9007 - val_loss: 0.1938 - val_accuracy: 0.9449
# Epoch 2/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1641 - accuracy: 0.9532 - val_loss: 0.1386 - val_accuracy: 0.9625
# Epoch 3/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1184 - accuracy: 0.9663 - val_loss: 0.1159 - val_accuracy: 0.9660
# Epoch 4/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0902 - accuracy: 0.9745 - val_loss: 0.0970 - val_accuracy: 0.9711
# Epoch 5/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0731 - accuracy: 0.9789 - val_loss: 0.0831 - val_accuracy: 0.9740
# Ustawiona wielość zbioru: 256
# Epoch 1/5
# 235/235 [==============================] - 3s 8ms/step - loss: 0.4509 - accuracy: 0.8792 - val_loss: 0.2351 - val_accuracy: 0.9340
# Epoch 2/5
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1991 - accuracy: 0.9437 - val_loss: 0.1678 - val_accuracy: 0.9532
# Epoch 3/5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1499 - accuracy: 0.9577 - val_loss: 0.1425 - val_accuracy: 0.9574
# Epoch 4/5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1222 - accuracy: 0.9641 - val_loss: 0.1259 - val_accuracy: 0.9638
# Epoch 5/5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1006 - accuracy: 0.9714 - val_loss: 0.1066 - val_accuracy: 0.9663

# %%
# Wygenerowanie wykresów
plt.figure(figsize=(12, 5))

# Dokładność
plt.subplot(1, 2, 1)
for i, history in enumerate(histories):
    plt.plot(history.history['val_accuracy'], label=f'Batch size: {batch_sizes[i]}')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()

# Strata
plt.subplot(1, 2, 2)
for i, history in enumerate(histories):
    plt.plot(history.history['val_loss'], label=f'Batch size: {batch_sizes[i]}')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()
