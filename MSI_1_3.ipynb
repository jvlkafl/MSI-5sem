# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('./datasets/StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
plt.plot(df['math score'],'o',markersize=4)
plt.xlabel('Student')
plt.ylabel('Math Score')
plt.title('Math Score of Students')
# Out:
# Text(0.5, 1.0, 'Math Score of Students')

# %%
plt.plot(df['math score'],'x', label='math',markersize=3)
plt.plot(df['reading score'],'o', label='reading',markersize=3)
plt.plot(df['writing score'],'v', label='writing',markersize=3)
plt.xlabel('Student')
plt.ylabel('Score')
plt.title('Scores of Students')
plt.legend()

# %%
plt.subplot(3,1,1)
plt.plot(df['math score'],'bx', label='math',markersize=3)
plt.ylabel('Score')
plt.legend()
plt.subplot(3,1,2)
plt.plot(df['reading score'],'ro', label='reading',markersize=3)
plt.ylabel('Score')
plt.legend()
plt.subplot(3,1,3)
plt.plot(df['writing score'],'gv', label='writing',markersize=3)
plt.xlabel('Student')
plt.ylabel('Score')
plt.tight_layout()
plt.legend()

# %%
plt.subplot(1,3,1)
plt.plot(df['math score'],'bx', label='math',markersize=3)
plt.ylabel('Score')
plt.legend()
plt.subplot(1,3,2)
plt.plot(df['reading score'],'ro', label='reading',markersize=3)
plt.ylabel('Score')
plt.legend()
plt.subplot(1,3,3)
plt.plot(df['writing score'],'gv', label='writing',markersize=3)
plt.xlabel('Student')
plt.ylabel('Score')
plt.legend()
