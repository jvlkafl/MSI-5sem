# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
import matplotlib.pyplot as plt
import os 
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'


# Wczytaj zbiór MNIST i znormalizuj dane (jak na poprzednich zajęciach)
# Stwórz dwa modele. Każdy z nich powinien mieć jedną warstwę ukrytą o 256 neuronach. 
# Różnica polega na dołączeniu w jednym z nich warstwy Dropout zaraz po 
# warstwie ukrytej - Dropout(0.2).
# Wytrenuj oba modele
# Stórz wykresy porównujące val_acc i acc obu modeli
# Out:
# c:\Users\Lenovo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
import numpy as np
num_classes = len(np.unique(y_train))
print(num_classes)
# Out:
# 10

# %%
model1 = Sequential()
model1.add(Flatten(input_shape=(28, 28)))
model1.add(Dense(256, activation='relu'))
model1.add(Dense(10, activation='softmax'))
model1.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 256)               200960
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2 = Sequential()
model2.add(Flatten(input_shape=(28, 28)))
model2.add(Dense(256, activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(10, activation='softmax'))
model2.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_4 (Dense)             (None, 256)               200960
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_5 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
#es = EarlyStopping(monitor = "val_loss", mode = "min", patience = 5)
EPOCHS = 100

# %%
history1 = model1.fit(x_train, y_train, epochs=EPOCHS, validation_split=0.2)
history2 = model2.fit(x_train, y_train, epochs=EPOCHS, validation_split=0.2)
# Out:
# Epoch 1/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.1163 - val_accuracy: 0.9787
# Epoch 2/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.1197 - val_accuracy: 0.9776
# Epoch 3/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.1101 - val_accuracy: 0.9786
# Epoch 4/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.1244 - val_accuracy: 0.9786
# Epoch 5/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.1373 - val_accuracy: 0.9758
# Epoch 6/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.1221 - val_accuracy: 0.9788
# Epoch 7/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.1214 - val_accuracy: 0.9797
# Epoch 8/100
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0033 - accuracy: 0.9987 - val_loss: 0.1228 - val_accuracy: 0.9795
# Epoch 9/100
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.1510 - val_accuracy: 0.9755
# Epoch 10/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.1495 - val_accuracy: 0.9764
# Epoch 11/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.1474 - val_accuracy: 0.9778
# Epoch 12/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.1497 - val_accuracy: 0.9780
# Epoch 13/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.1358 - val_accuracy: 0.9805
# Epoch 14/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.1459 - val_accuracy: 0.9798
# Epoch 15/100
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1669 - val_accuracy: 0.9777
# Epoch 16/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.1592 - val_accuracy: 0.9771
# Epoch 17/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.1371 - val_accuracy: 0.9809
# Epoch 18/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.1485 - val_accuracy: 0.9791
# Epoch 19/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.1541 - val_accuracy: 0.9792
# Epoch 20/100
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.1692 - val_accuracy: 0.9783
# Epoch 21/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.1587 - val_accuracy: 0.9794
# Epoch 22/100
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1579 - val_accuracy: 0.9790
# Epoch 23/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.1639 - val_accuracy: 0.9795
# Epoch 24/100
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.1595 - val_accuracy: 0.9794
# Epoch 25/100
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.1600 - val_accuracy: 0.9799
# Epoch 26/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.1602 - val_accuracy: 0.9799
# Epoch 27/100
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.1639 - val_accuracy: 0.9783
# Epoch 28/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.1724 - val_accuracy: 0.9783
# Epoch 29/100
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1699 - val_accuracy: 0.9789
# Epoch 30/100
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.1727 - val_accuracy: 0.9800
# Epoch 31/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.2120 - val_accuracy: 0.9753
# Epoch 32/100
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.1750 - val_accuracy: 0.9792
# Epoch 33/100
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1603 - val_accuracy: 0.9806
# Epoch 34/100
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.1915 - val_accuracy: 0.9770
# Epoch 35/100
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.1996 - val_accuracy: 0.9771
# Epoch 36/100
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.2017 - val_accuracy: 0.9773
# Epoch 37/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.1907 - val_accuracy: 0.9797
# Epoch 38/100
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.1952 - val_accuracy: 0.9789
# Epoch 39/100
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.1811 - val_accuracy: 0.9794
# Epoch 40/100
# 1500/1500 [==============================] - 30s 20ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.2064 - val_accuracy: 0.9787
# Epoch 41/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.1966 - val_accuracy: 0.9788
# Epoch 42/100
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.1969 - val_accuracy: 0.9794
# Epoch 43/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.2013 - val_accuracy: 0.9778
# Epoch 44/100
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.2280 - val_accuracy: 0.9778
# Epoch 45/100
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1882 - val_accuracy: 0.9782
# Epoch 46/100
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.2004 - val_accuracy: 0.9778
# Epoch 47/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.2231 - val_accuracy: 0.9772
# Epoch 48/100
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.2031 - val_accuracy: 0.9801
# Epoch 49/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 7.5114e-04 - accuracy: 0.9999 - val_loss: 0.1807 - val_accuracy: 0.9815
# Epoch 50/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.2495 - val_accuracy: 0.9770
# Epoch 51/100
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.1976 - val_accuracy: 0.9797
# Epoch 52/100
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.2337 - val_accuracy: 0.9797
# Epoch 53/100
# 1500/1500 [==============================] - 11s 8ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.2172 - val_accuracy: 0.9803
# Epoch 54/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.2388 - val_accuracy: 0.9778
# Epoch 55/100
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.2108 - val_accuracy: 0.9792
# Epoch 56/100
# 1500/1500 [==============================] - 10s 6ms/step - loss: 4.8773e-04 - accuracy: 0.9999 - val_loss: 0.2043 - val_accuracy: 0.9788
# Epoch 57/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.2873 - val_accuracy: 0.9752
# Epoch 58/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.2179 - val_accuracy: 0.9805
# Epoch 59/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.2185 - val_accuracy: 0.9802
# Epoch 60/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 5.5542e-04 - accuracy: 0.9998 - val_loss: 0.2193 - val_accuracy: 0.9797
# Epoch 61/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.2433 - val_accuracy: 0.9768
# Epoch 62/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 0.2246 - val_accuracy: 0.9809
# Epoch 63/100
# 1500/1500 [==============================] - 14s 9ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.2619 - val_accuracy: 0.9783
# Epoch 64/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.2385 - val_accuracy: 0.9787
# Epoch 65/100
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.2303 - val_accuracy: 0.9798
# Epoch 66/100
# 1500/1500 [==============================] - 35s 24ms/step - loss: 5.7884e-04 - accuracy: 0.9999 - val_loss: 0.2323 - val_accuracy: 0.9798
# Epoch 67/100
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.2512 - val_accuracy: 0.9793
# Epoch 68/100
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.2410 - val_accuracy: 0.9805
# Epoch 69/100
# 1500/1500 [==============================] - 32s 22ms/step - loss: 6.7129e-04 - accuracy: 0.9998 - val_loss: 0.2448 - val_accuracy: 0.9803
# Epoch 70/100
# 1500/1500 [==============================] - 27s 18ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.2415 - val_accuracy: 0.9797
# Epoch 71/100
# 1500/1500 [==============================] - 27s 18ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.2079 - val_accuracy: 0.9830
# Epoch 72/100
# 1500/1500 [==============================] - 35s 23ms/step - loss: 9.6402e-06 - accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9833
# Epoch 73/100
# 1500/1500 [==============================] - 37s 25ms/step - loss: 1.5579e-06 - accuracy: 1.0000 - val_loss: 0.2065 - val_accuracy: 0.9838
# Epoch 74/100
# 1500/1500 [==============================] - 47s 31ms/step - loss: 9.7396e-07 - accuracy: 1.0000 - val_loss: 0.2064 - val_accuracy: 0.9837
# Epoch 75/100
# 1500/1500 [==============================] - 52s 35ms/step - loss: 6.4675e-07 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9837
# Epoch 76/100
# 1500/1500 [==============================] - 49s 33ms/step - loss: 4.2822e-07 - accuracy: 1.0000 - val_loss: 0.2065 - val_accuracy: 0.9836
# Epoch 77/100
# 1500/1500 [==============================] - 50s 34ms/step - loss: 2.6577e-07 - accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9831
# Epoch 78/100
# 1500/1500 [==============================] - 36s 24ms/step - loss: 1.6211e-07 - accuracy: 1.0000 - val_loss: 0.2072 - val_accuracy: 0.9832
# Epoch 79/100
# 1500/1500 [==============================] - 32s 21ms/step - loss: 9.5260e-08 - accuracy: 1.0000 - val_loss: 0.2078 - val_accuracy: 0.9833
# Epoch 80/100
# 1500/1500 [==============================] - 44s 29ms/step - loss: 6.1301e-08 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9838
# Epoch 81/100
# 1500/1500 [==============================] - 36s 24ms/step - loss: 3.6858e-08 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9837
# Epoch 82/100
# 1500/1500 [==============================] - 48s 32ms/step - loss: 2.4031e-08 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9839
# Epoch 83/100
# 1500/1500 [==============================] - 31s 21ms/step - loss: 1.6130e-08 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9842
# Epoch 84/100
# 1500/1500 [==============================] - 31s 21ms/step - loss: 1.1841e-08 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9838
# Epoch 85/100
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0084 - accuracy: 0.9983 - val_loss: 0.2771 - val_accuracy: 0.9783
# Epoch 86/100
# 1500/1500 [==============================] - 44s 29ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.2746 - val_accuracy: 0.9802
# Epoch 87/100
# 1500/1500 [==============================] - 33s 22ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.2621 - val_accuracy: 0.9787
# Epoch 88/100
# 1500/1500 [==============================] - 32s 22ms/step - loss: 2.9828e-04 - accuracy: 0.9999 - val_loss: 0.2505 - val_accuracy: 0.9802
# Epoch 89/100
# 1500/1500 [==============================] - 32s 22ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.2854 - val_accuracy: 0.9783
# Epoch 90/100
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.2877 - val_accuracy: 0.9777
# Epoch 91/100
# 1500/1500 [==============================] - 47s 31ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.2706 - val_accuracy: 0.9795
# Epoch 92/100
#   60/1500 [>.............................] - ETA: 52s - loss: 0.0064 - accuracy: 0.9995
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Lenovo\Documents\GitHub\MSI-5sem\7.3 Dropout-zadania.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/GitHub/MSI-5sem/7.3%20Dropout-zadania.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> history1 = model1.fit(x_train, y_train, epochs=EPOCHS, validation_split=0.2)
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/GitHub/MSI-5sem/7.3%20Dropout-zadania.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> history2 = model2.fit(x_train, y_train, epochs=EPOCHS, validation_split=0.2)
#
# File c:\Users\Lenovo\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Lenovo\anaconda3\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File c:\Users\Lenovo\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Lenovo\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Lenovo\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\Lenovo\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\Lenovo\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Lenovo\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File c:\Users\Lenovo\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
loss = history1.history['loss']
val_loss = history1.history['val_loss']
acc = history1.history['accuracy']
val_acc = history1.history['val_accuracy']
loss2 = history2.history['loss']
val_loss2 = history2.history['val_loss']
acc2 = history2.history['accuracy']
val_acc2 = history2.history['val_accuracy']
plt.subplot(1,2,1)
plt.plot(loss, label = "loss")
plt.plot(val_loss, label = "val_loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.subplot(1,2,2)
plt.plot(loss2, label = "loss2")
plt.plot(val_loss2, label = "val_loss2")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()
plt.tight_layout()

# %%
loss2 = history2.history['loss']
val_loss2 = history2.history['val_loss']
acc2 = history2.history['accuracy']
val_acc2 = history2.history['val_accuracy']
plt.subplot(1,2,1)
plt.plot(acc, label = "accuarcy")
plt.plot(val_acc, label = "val_accuarcy")
plt.xlabel("epoch")
plt.ylabel("accuarcy")
plt.legend()
plt.subplot(1,2,2)
plt.plot(acc2, label = "accuarcy2")
plt.plot(val_acc2, label = "val_accuarcy2")
plt.xlabel("epoch")
plt.ylabel("accuarcy")
plt.legend()


plt.show()
plt.tight_layout()
